# %% [markdown]
# # Nivell 1
# ##1. Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades. Pots obtenir més informació del seu càlcul en: 🔗 Índice de masa corporal IMC que es y como se calcula.
# La funció ha de classificar el resultat en les seves respectives categories.
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduïdes per l’usuari/a no estan en el format adequat o no pren valors raonables.

# %%
def imc():
    while True: #creamos un bucle hasta que se introduzcan datos correctos
        try:
            altura = float(input('Ingresa tu altura en metros (por ejemplo 1.65): '))
            peso = float(input('Ingresa tu peso en kilos (por ejemplo 55): '))
            break #detiene el while, ya tenemos los datos correctos
        except ValueError: # si se indroduce la altura o peso incorrectamente, eso lanza un ValueError y Python abandona inmediatamente el bloque try y salta al except ValueError, no llega a ninguna linea posterior, no llega el break
            print('Por favor, ingresa solo números válidos (usa punto decimal, no coma).')

    indice = peso / (altura ** 2)
    print('Tu IMC es:', round(indice, 2))

imc()
# Out:
# Ingresa tu altura en metros (por ejemplo 1.65): 1.74
# Ingresa tu peso en kilos (por ejemplo 55): 67
# Tu IMC es: 22.13

# %% [markdown]
# ##2. Convertidor de temperatures
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re).
#
# Selecciona almenys 2 conversors, de tal manera que en introduir una temperatura retorni, com a mínim, dues conversions, de manera que es puguin guardar (recorda que un print() no es pot guardar mai).
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduides per l’usuari/a no estan en el format adequat.
#
# (EXTRA): Pensa una manera d’emmagatzemar totes les possibles conversions en un sol objecte (Llista? Diccionari? DataFrame?) en comptes d’escriure molts if else en funció de la temperatura d’origen i la temperatura de destí.

# %%
def convertidor():
    while True: # 1 bucle: hasta que se introduzca la temperatura correcta
        try:
            temperatura = float(input("Introduce la temperatura: "))
            break  # detiene el while, ya tenemos los datos correctos
        except ValueError:
            print('Por favor, ingresa solo números válidos (usa punto decimal, no coma).')

    while True: # 2 bucle: hasta que se introduzca C o F
        grados = input("Introduce C para Celsius o F para Fahrenheit: ").upper()
        if grados in ['C', 'F']:
            break  # si es correcto, sale del bucle
        else:
            print('Por favor, ingresa sólo C o F.')

    # Conversiones
    if grados == 'C':
        celsius = temperatura
        fahrenheit = round((9/5 * celsius) + 32, 2)
        kelvin = round(celsius + 273.15, 2)
        rankine = round(9/5 * (celsius + 273.15), 2)
        temperaturas = (celsius, fahrenheit, kelvin, rankine)
        print('Las conversiones son en orden: Celsius, Fahrenheit, Kelvin, Rankine')

    elif grados == 'F':
        fahrenheit = temperatura
        celsius = round((fahrenheit - 32) * 5/9, 2)
        kelvin = round(celsius + 273.15, 2)
        rankine = round(fahrenheit + 459.67, 2)
        temperaturas = (celsius, fahrenheit, kelvin, rankine)
        print('Las conversiones son en orden: Celsius, Fahrenheit, Kelvin, Rankine')

    return temperaturas

convertidor()
# Out:
# Introduce la temperatura: 40
# Introduce C para Celsius o F para Fahrenheit: s
# Por favor, ingresa sólo C o F.
# Introduce C para Celsius o F para Fahrenheit: c
# Las conversiones son en orden: Celsius, Fahrenheit, Kelvin, Rankine
# (40.0, 104.0, 313.15, 563.67)

# %% [markdown]
# ##3. Comptador de paraules d'un text.
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula. Intenta que es gestionin totes les casuístiques possibles que facin que el programa no funcioni correctament.
#
# (EXTRA): Quina és la llargada mitjana de les paraules del text que has escrit? “Hola com va?” hauria de retornar (4+3+2) / 3 = 3

# %%
import string

def contador():
  text = input('Introduce un texto, te diré cada vez que aparece cada palabra y cual es la media de la longitud de las palabras: ')
  text = text.lower()  # todo minúsculas

  for char in string.punctuation:  # string.punctuation es una cadena que contiene los simbolos mas comunes = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
    text = text.replace(char, '')  # iteramos uno de estos simbolos a uno, y si lo encuentra en text, lo elimina (substituye por nada)

  palabras = text.split() # funcion que divide text en palabras y las pone en una lista
  contador_palabras = {} # definimos un diccionario. Perfecto para lo que queremos. Palabra:Numero de veces que aparece la palabra

  for palabra in palabras: # iteramos por la lista palabras y contamos cuantas veces aparece cada una y las ponemos en el diccionario
    if palabra in contador_palabras:
        contador_palabras[palabra] += 1 # como la palabra ya a aparedido antes, solo sumamos el valor +1
    else:
        contador_palabras[palabra] = 1 # aqui ponemos palabra por palabra (dupla clave valor) en el diccionario

  suma_longituds = sum(len(p) for p in palabras) # iteramos por todas las palabras y con len sabemos la longitud de cada palabra, las sumamos todas
  media = suma_longituds / len(palabras) # para calcular la media es solo dividir por el numero de palabras

  print('Contador de palabras:') # impriminos los resultados iterando por el diccionario
  for palabra, veces in contador_palabras.items(): # usamos .items() porque queremos los pares (clave, valor), .keys()solo para las claves y .values() solo para los valores

    print(f'{palabra}: {veces} veces')

  print(f'\nLongitud media de las palabras: {media:.2f}')

contador()
# Out:
# Introduce un texto, te diré cada vez que aparece cada palabra y cual es la media de la longitud de las palabras: Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviant les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment, juntament amb una llista amb els valors associats a la clau repetida.
# Contador de palabras:
# resulta: 1 veces
# que: 2 veces
# el: 3 veces
# client: 1 veces
# té: 1 veces
# una: 2 veces
# enquesta: 1 veces
# molt: 1 veces
# antiga: 1 veces
# semmagatzema: 1 veces
# en: 2 veces
# un: 2 veces
# diccionari: 2 veces
# i: 3 veces
# els: 5 veces
# resultats: 1 veces
# necessita: 1 veces
# al: 1 veces
# revés: 1 veces
# és: 2 veces
# a: 2 veces
# dir: 1 veces
# intercanviant: 1 veces
# les: 1 veces
# claus: 2 veces
# valors: 3 veces
# original: 1 veces
# són: 1 veces
# ...

# %% [markdown]
# ##4. Diccionari invers (amb possibilitat de duplicats)
#
# Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviant les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment, juntament amb una llista amb els valors associats a la clau repetida.

# %%
def invertir_diccionario(dic):
    dic_inverso = {} # creamos el diccionario inverso
    duplicados = {} # creamos un diccionario para los duplicados

    for clave, valor in dic.items(): # iteramos el diccionario (clave:valor)
        if valor not in dic_inverso: # si el valor no está ya, lo ponemos en dic_invers (el diccionario no admite 2 claves iguales)
            dic_inverso[valor] = clave
        else:                       # si el valor ya está (duplicado)
            if valor not in duplicados:
                duplicados[valor] = [dic_inverso[valor]] # lo añadimos a duplicados ya que no está
            duplicados[valor].append(clave) # guardamos en una lista las claves que son iguales
            dic_inverso[valor] = duplicados[valor]  # reflejamos asi en dic_invers todas las claves que comparten el mismo valor

    # Mensaje de advertencia centralizado
    if duplicados: # solo se considera True si no es vacio
        print('Hemos encontrado valores duplicados:')
        for valor, claves in duplicados.items():
            print(f' {valor} - {claves}')

    return dic_inverso

# Ejemplo: lo substituiremos por el diccionario del cliente cuando nos lo de
enquesta = {'Ana': 7,'Dragos': 9,'Laura': 8,'Luis': 9}
resultado = invertir_diccionario(enquesta)
print('\nDiccionario Inverso:')
print(resultado)
# Out:
# Hemos encontrado valores duplicados:
#  9 - ['Dragos', 'Luis']
#
# Diccionario Inverso:
# {7: 'Ana', 9: ['Dragos', 'Luis'], 8: 'Laura'}

# %% [markdown]
# # Nivell 2
# ##1. Comptador i endreçador de paraules d'un text.
#
# El client va quedar content amb el comptador de paraules, però ara vol llegir arxius TXT i que calculi la freqüència de cada paraula ordenades dins de les entrades habituals del diccionari segons la lletra amb la qual comencen, és a dir, les claus han d'anar de la A a la Z i dins de la A hem d'anar de la A la Z. Per exemple, per a l'arxiu "tu_me_quieres_blanca.txt" la sortida esperada seria:

# %%
import string

def contador_por_inicial():
    # pedir texto al usuario, si queremos cargar un archivo: with open(nombre_archivo, "r", encoding="utf-8") as f: texto = f.read().lower()  # todo minúsculas
    texto = input("Introduce el texto: ").lower()  # todo minúsculas

    for char in string.punctuation: # limpiamos el texto, como en el Nivel 1
        texto = texto.replace(char, '')

    palabras = texto.split() # funcion que divide text en palabras y las pone en una lista

    contador_palabras = {} # definimos un diccionario. Perfecto para lo que queremos. Palabra:Numero de veces que aparece la palabra
    for palabra in palabras: # definimos un diccionario. Perfecto para lo que queremos. Palabra:Numero de veces que aparece la palabra
      if palabra in contador_palabras:
        contador_palabras[palabra] += 1 # como la palabra ya a aparedido antes, solo sumamos el valor +1
      else:
        contador_palabras[palabra] = 1

    ordenado = {} # agrupamos por letra inicial
    for palabra, freq in contador_palabras.items():
        inicial = palabra[0]  # la primera letra
        if inicial not in ordenado:
            ordenado[inicial] = {}
        ordenado[inicial][palabra] = freq

    for inicial in ordenado: # ordenamos las palabras
        ordenado[inicial] = dict(sorted(ordenado[inicial].items()))

    ordenado = dict(sorted(ordenado.items())) # ordenamos letras principales

    return ordenado

# Ejemplo
resultado = contador_por_inicial() #si tuvieramos un archivo: resultado = contador_por_inicial("arquivo.txt")
print("\nDiccionari final per inicial:")
for inicial, palabras_dict in resultado.items():
    print(f"{inicial}: {palabras_dict}")
# Out:
# Introduce el texto: 2. Conversió de tipus de dades.  El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir. Exemple de la llista que rep el client:
#
# Diccionari final per inicial:
# 2: {'2': 1}
# c: {'client': 2, 'conversió': 1, 'convertir': 2}
# d: {'dades': 2, 'de': 4, 'dues': 1}
# e: {'el': 2, 'elements': 2, 'els': 2, 'en': 1, 'es': 2, 'estan': 1, 'estaran': 1, 'exemple': 1}
# f: {'flotants': 1}
# g: {'generar': 1}
# i: {'i': 2}
# l: {'la': 2, 'laltra': 1, 'llista': 2, 'llistes': 1}
# n: {'necessita': 1, 'no': 1}
# o: {'on': 2}
# p: {'poder': 2, 'primera': 1}
# q: {'que': 3}
# r: {'rep': 2}
# t: {'tipus': 1, 'tots': 1}
# u: {'una': 1}
# v: {'van': 2}

# %%
import string

def contador_por_inicial(nombre_archivo):
    # cargamos el archivo
    try:
        with open(nombre_archivo, "r", encoding="utf-8") as f:
            texto = f.read().lower()  # todo minúsculas
    except FileNotFoundError:
        print(f"Error: No se encuentra el archivo '{nombre_archivo}'")
        return {}
    except Exception as e:
        print(f"Error al leer el archivo: {e}")
        return {}

    # limpiamos el texto de puntuación
    for char in string.punctuation:
        texto = texto.replace(char, '')

    palabras = texto.split()  # funcion que divide texto en palabras y las pone en una lista
    contador_palabras = {}  # definimos un diccionario. Perfecto para lo que queremos. Palabra:Numero de veces que aparece la palabra

    for palabra in palabras:
        if palabra in contador_palabras:
            contador_palabras[palabra] += 1  # como la palabra ya ha aparecido antes, solo sumamos el valor +1
        else:
            contador_palabras[palabra] = 1

    ordenado = {}  # agrupamos por letra inicial
    for palabra, freq in contador_palabras.items():
        inicial = palabra[0]  # la primera letra
        if inicial not in ordenado:
            ordenado[inicial] = {}
        ordenado[inicial][palabra] = freq

    for inicial in ordenado:  # ordenamos las palabras
        ordenado[inicial] = dict(sorted(ordenado[inicial].items()))

    ordenado = dict(sorted(ordenado.items()))  # ordenamos letras principales

    return ordenado


# subimos el archivo en Colab
from google.colab import files
print("Sube tu archivo .txt:")
uploaded = files.upload()
nombre_archivo = list(uploaded.keys())[0]  # obtenemos el nombre del archivo subido
resultado = contador_por_inicial(nombre_archivo)

if resultado:
    print("\nDiccionario final por iniciales:")
    for inicial, palabras_dict in resultado.items():
        print(f"{inicial}: {palabras_dict}")
# Out:
# Sube tu archivo .txt:
#      <input type="file" id="files-6eed9918-7f76-42d7-b8d3-12c6794654a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6eed9918-7f76-42d7-b8d3-12c6794654a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ##2. Conversió de tipus de dades.
#
# El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir. Exemple de la llista que rep el client:

# %%
def convertir_lista(lista):
    convertidos = []
    no_convertidos = []

    for element in lista:
        # si el elemento es una lista o tupla, procesamos recursivamente
        if isinstance(element, (list, tuple)):
            conv, no_conv = convertir_lista(element)
            convertidos.extend(conv)
            no_convertidos.extend(no_conv)
        else:
            # limpiamos espacios y convertimos comas a puntos
            valor = str(element).strip().replace(',', '.')

            try:
                convertidos.append(float(valor))
            except ValueError:
                no_convertidos.append(element)

    return convertidos, no_convertidos


# Ejemplo
data = ['1.3', 'one', '1e10', 'seven', '3-1/2', ('2', 1, 1.4, 'not-a-number'), [1, 2, '3', '3.4']]
convertidos, no_convertidos = convertir_lista(data)
print("Convertidos a float:", convertidos)
print("No convertidos:", no_convertidos)
# Out:
# Convertidos a float: [1.3, 10000000000.0, 2.0, 1.0, 1.4, 1.0, 2.0, 3.0, 3.4]
# No convertidos: ['one', 'seven', '3-1/2', 'not-a-number']

# %% [markdown]
# # Nivell 3
# ##1. Generador de Contrasenyes
#
# Explora el funcionament del mòdul random de la llibreria numpy. 🔗 Random module in NumPy
#
# En aquest punt, el client ha detectat un problema amb les contrasenyes que utilitzen els seus treballadors. Asdf1234, dates d’aniversari o similars. Per a solucionar-ho ens ha encarregat una funció de Python que generi contrasenyes més segures. La funció ha de dependre dels següents paràmetres:
#
# longitud (int): Longitud de la contrasenya
# majuscules (bool = True): Si hi ha d’aparèixer majúscules
# minuscules (bool = True): Si hi ha d’aparèixer minúscules
# numeros (bool = True): Si hi ha d’aparèixer números
# signes (bool = False): Si hi ha d’aparèixer caràcters especials (,-$? o similars)
# Així doncs, si executem la funció de la següent manera:
#
# crear_contrasenya(10, True, True, True, True)
#
# Hauríem d’obtenir un output (que hem de poder guardar) de l’estil:
#
# 9Er,5Vn8P$
#
# Assegura’t que es compleixin tots els criteris, i que aquestes contrasenyes siguin realment aleatòries.
#
# (EXTRA) Explora com podríem fer que la funció copiés la contrasenya automàticament al porta papers de l’ordinador (com si l’haguéssim seleccionat i fet ctrl+copy).

# %%
import numpy as np
import string
import pyperclip  # para copiar al portapapeles

def crear_contrasenya(longitud, majuscules=True, minuscules=True, numeros=True, signes=False):
    # validamos que la longitud sea positiva
    if longitud <= 0:
        print("La longitud ha de ser un número positivo.")
        return None

    caracters = ''
    opcions = []

    # añadimos los tipos de caracteres seleccionados
    if majuscules:
        opcions.append(list(string.ascii_uppercase))
        caracters += string.ascii_uppercase
    if minuscules:
        opcions.append(list(string.ascii_lowercase))
        caracters += string.ascii_lowercase
    if numeros:
        opcions.append(list(string.digits))
        caracters += string.digits
    if signes:
        opcions.append(list("!@#$%&*?,-$"))
        caracters += "!@#$%&*?,-$"

    # verificamos que haya al menos un tipo seleccionado
    if not caracters:
        print("Debes seleccionar al menos un tipo de carácter.")
        return None

    # nos aseguramos de que aparezca al menos un carácter de cada tipo seleccionado
    contrasenya = [np.random.choice(opcion) for opcion in opcions]

    # rellenamos hasta la longitud deseada con caracteres aleatorios
    if longitud > len(contrasenya):
        contrasenya += list(np.random.choice(list(caracters), longitud - len(contrasenya)))

    # mezclamos todo para que sea realmente aleatorio
    np.random.shuffle(contrasenya)

    # convertimos la lista en string
    contrasenya_final = ''.join(contrasenya[:longitud])  # nos aseguramos de la longitud exacta

    # copiamos automáticamente al portapapeles
    try:
        pyperclip.copy(contrasenya_final)
        print("Contrasenya generada:", contrasenya_final)
        print("✓ Contraseña copiada al portapapeles")
    except:
        print("Contrasenya generada:", contrasenya_final)
        print("(No se pudo copiar al portapapeles automáticamente)")

    return contrasenya_final


# Ejemplo de uso
contrasenya = crear_contrasenya(10, True, True, True, True)
print("\nContrasenya guardada en variable:", contrasenya)
# Out:
# Contrasenya generada: R9K8?%sso0
# (No se pudo copiar al portapapeles automáticamente)
#
# Contrasenya guardada en variable: R9K8?%sso0

# %% [markdown]
# ##2. Processament de dades simple
#
# Una companya de feina ens ha demanat un favor, aprofitant que sap que estem aprenent a programar. Té un històric de partits de futbol català en un fitxer, on hi ha emmagatzemat els noms dels equips i els resultats. Necessita que processem les dades de manera automàtica, per extreure’n els resultats que necessita.
#
# Utilitza el fitxer "historic_partits.txt"
#
# Necessita un programa que retorni:
#
# El nombre total de gols que ha fet cada equip.
# El nom de l’equip més golejador.
# El nom de l’equip més golejat
# La classificació global (cada victòria: 3 pts, empat 1 pts, derrota 0 pts)
# Com a referència, els equips amb més punts serien els següents:
#
# imatge resultat partits
# Pots utilitzar el format que et sigui més convenient.

# %%
def procesar_partidos(ruta_archivo):

    # Diccionario para almacenar estadísticas de cada equipo
    equipos = {}

    try:
        with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
            for linea in archivo:
                linea = linea.strip()
                if not linea:  # Saltar líneas vacías
                    continue

                # Formato esperado: Equipo1 goles1-goles2 Equipo2
                # Ejemplo: Girona FC 3-1 Sabadell
                partes = linea.split()

                # Buscar el guión que separa los goles
                indice_resultado = -1
                for i, parte in enumerate(partes):
                    if '-' in parte:
                        indice_resultado = i
                        break

                if indice_resultado == -1:
                    continue  # Línea mal formateada

                # Extraer nombres de equipos y resultado
                equipo1 = ' '.join(partes[:indice_resultado])
                resultado = partes[indice_resultado]
                equipo2 = ' '.join(partes[indice_resultado + 1:])

                # Extraer goles
                try:
                    goles1, goles2 = map(int, resultado.split('-'))
                except ValueError:
                    continue  # Resultado mal formateado

                # Inicializar equipos si no existen
                if equipo1 not in equipos:
                    equipos[equipo1] = {
                        'goles_favor': 0,
                        'goles_contra': 0,
                        'partidos_ganados': 0,
                        'partidos_empatados': 0,
                        'partidos_perdidos': 0,
                        'puntos': 0
                    }

                if equipo2 not in equipos:
                    equipos[equipo2] = {
                        'goles_favor': 0,
                        'goles_contra': 0,
                        'partidos_ganados': 0,
                        'partidos_empatados': 0,
                        'partidos_perdidos': 0,
                        'puntos': 0
                    }

                # Actualizar goles
                equipos[equipo1]['goles_favor'] += goles1
                equipos[equipo1]['goles_contra'] += goles2
                equipos[equipo2]['goles_favor'] += goles2
                equipos[equipo2]['goles_contra'] += goles1

                # Actualizar puntos y resultados
                if goles1 > goles2:  # Gana equipo1
                    equipos[equipo1]['partidos_ganados'] += 1
                    equipos[equipo1]['puntos'] += 3
                    equipos[equipo2]['partidos_perdidos'] += 1
                elif goles1 < goles2:  # Gana equipo2
                    equipos[equipo2]['partidos_ganados'] += 1
                    equipos[equipo2]['puntos'] += 3
                    equipos[equipo1]['partidos_perdidos'] += 1
                else:  # Empate
                    equipos[equipo1]['partidos_empatados'] += 1
                    equipos[equipo1]['puntos'] += 1
                    equipos[equipo2]['partidos_empatados'] += 1
                    equipos[equipo2]['puntos'] += 1

        return equipos

    except FileNotFoundError:
        print(f"Error: No se encontró el archivo '{ruta_archivo}'")
        return None
    except Exception as e:
        print(f"Error al procesar el archivo: {e}")
        return None


def mostrar_estadisticas(equipos):

    # muestra todas las estadísticas calculadas
    if not equipos:
        print("No hay datos para mostrar.")
        return

    print("=" * 80)
    print("ESTADÍSTICAS DE EQUIPOS - FÚTBOL CATALÁN")
    print("=" * 80)
    print()

    # 1. Goles totales por equipo
    print("1. GOLES TOTALES POR EQUIPO:")
    print("-" * 50)
    goles_ordenados = sorted(equipos.items(),
                            key=lambda x: x[1]['goles_favor'],
                            reverse=True)

    for equipo, stats in goles_ordenados:
        print(f"   {equipo}: {stats['goles_favor']} goles")
    print()

    # 2. Equipo más goleador
    equipo_mas_goleador = max(equipos.items(), key=lambda x: x[1]['goles_favor'])
    print("2. EQUIPO MÁS GOLEADOR:")
    print("-" * 50)
    print(f"   {equipo_mas_goleador[0]} con {equipo_mas_goleador[1]['goles_favor']} goles")
    print()

    # 3. Equipo más goleado
    equipo_mas_goleado = max(equipos.items(), key=lambda x: x[1]['goles_contra'])
    print("3. EQUIPO MÁS GOLEADO:")
    print("-" * 50)
    print(f"   {equipo_mas_goleado[0]} con {equipo_mas_goleado[1]['goles_contra']} goles en contra")
    print()

    # 4. Clasificación global
    print("4. CLASIFICACIÓN GLOBAL:")
    print("-" * 50)
    clasificacion = sorted(equipos.items(),
                          key=lambda x: (x[1]['puntos'], x[1]['goles_favor']),
                          reverse=True)

    print(f"{'Pos':<5} {'Equipo':<25} {'PG':<5} {'PE':<5} {'PP':<5} {'GF':<5} {'GC':<5} {'Pts':<5}")
    print("-" * 80)

    for pos, (equipo, stats) in enumerate(clasificacion, 1):
        print(f"{pos:<5} {equipo:<25} {stats['partidos_ganados']:<5} "
              f"{stats['partidos_empatados']:<5} {stats['partidos_perdidos']:<5} "
              f"{stats['goles_favor']:<5} {stats['goles_contra']:<5} "
              f"{stats['puntos']:<5}")

    print("=" * 80)


# Programa principal
if __name__ == "__main__":
    # Ruta al archivo (ajusta según tu ubicación)
    ruta_archivo = "/content/historic partits.txt"

    print("Procesando histórico de partidos...")
    print()

    # Procesar el archivo
    equipos = procesar_partidos(ruta_archivo)

    # Mostrar estadísticas
    if equipos:
        mostrar_estadisticas(equipos)
    else:
        print("No se pudieron procesar los datos.")
# Out:
# Procesando histórico de partidos...
#
# ...
# ESTADÍSTICAS DE EQUIPOS - FÚTBOL CATALÁN
# ...
#
# 1. GOLES TOTALES POR EQUIPO:
# --------------------------------------------------
#    Figueres: 161 goles
#    Llagostera: 159 goles
#    Vilafranca: 157 goles
#    Terrassa: 147 goles
#    Cornellà: 147 goles
#    Sabadell: 141 goles
#    Girona FC: 139 goles
#    Badalona: 134 goles
#    Olot: 132 goles
#    RCD Espanyol: 131 goles
#    Nàstic de Tarragona: 130 goles
#    Lleida Esportiu: 129 goles
#    FC Barcelona: 125 goles
#    Sant Andreu: 123 goles
#    Granollers: 122 goles
#    Reus Deportiu: 119 goles
#    Cerdanyola: 117 goles
#    Manlleu: 106 goles
#    Prat: 106 goles
#    Europa: 93 goles
#
# 2. EQUIPO MÁS GOLEADOR:
# --------------------------------------------------
#    Figueres con 161 goles
#
# 3. EQUIPO MÁS GOLEADO:
# --------------------------------------------------
#    Vilafranca con 172 goles en contra
#
# 4. CLASIFICACIÓN GLOBAL:
# ...
